# %%
# %matplotlib inline
import os
import zipfile
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpim
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# %%
"""local_zip = '/home/fabian/carclass.zip' #Zip File Location Path
zip_ref = zipfile.ZipFile(local_zip, 'r') # Read the local_zip
zip_ref.extractall('/home/fabian/') # All images will be located in /tmp/horse-or-man
zip_ref.close() # Close the File"""
# Out:
# "local_zip = '/home/fabian/carclass.zip' #Zip File Location Path\nzip_ref = zipfile.ZipFile(local_zip, 'r') # Read the local_zip\nzip_ref.extractall('/home/fabian/') # All images will be located in /tmp/horse-or-man\nzip_ref.close() # Close the File"

# %%
"""local_zip = '/home/fabian/carval.zip' #Zip File Location Path
zip_ref = zipfile.ZipFile(local_zip, 'r') # Read the local_zip
zip_ref.extractall('/home/fabian/') # All images will be located in /tmp/horse-or-man
zip_ref.close() # Close the File"""
# Out:
# "local_zip = '/home/fabian/carval.zip' #Zip File Location Path\nzip_ref = zipfile.ZipFile(local_zip, 'r') # Read the local_zip\nzip_ref.extractall('/home/fabian/') # All images will be located in /tmp/horse-or-man\nzip_ref.close() # Close the File"

# %%
train_ferrari_dir = os.path.join('/home/fabian/carclass/ferrari/train')
train_porsche_dir = os.path.join('/home/fabian/carclass/porsche/train')

validation_ferrari_dir = os.path.join('/home/fabian/carval/ferrari')
validation_porsche_dir = os.path.join('/home/fabian/carval/porsche')

# %%
train_ferrari_names = os.listdir(train_ferrari_dir)
print(train_ferrari_names[:10])

train_porsche_names = os.listdir(train_porsche_dir)
print(train_porsche_names[:10])
# Out:
# ['945812.jpg', '757610.jpg', 'novitec_rosso_ferrari_458_speciale_2014-wide.jpg', 'wp2188196.jpg', 'ferrari-488-pista-2560x1440-2019-cars-supercar-19484.jpg', '2019-NOVITEC-Ferrari-Portofino-Front-Three-Quarter-Wallpaper-21.jpg', '2018-ferrari-portofino-4k-wallpaper-78149-3553871.png', 'ferrari_488_pista_4k_2018_2-HD.jpg', 'ferrari-berlinetta-f12-car-wallpaper-top-automotive-magazine.jpg', 'image15.jpeg']
# ['porsche-cayenne.jpg', '1641470.jpg', 'wp2676980.jpg', 'techart_porsche_cayenne_turbo_2018_3-HD.jpg', 'e0b7885428f49c520a23ab4bcd153580.jpg', 'porsche-918-spyder-wallpaper-1080p-188603.jpg', '180019.jpg', 'WP0AB2A99KS115453_36e3964a86754423.jpg', 'wp4412908.jpg', '2020-porsche-911-turbo.jpg']

# %%
print('total training ferrari images:', len(os.listdir(train_ferrari_dir)))
print('total training porsche images:', len(os.listdir(train_porsche_dir)))
# Out:
# total training ferrari images: 450
# total training porsche images: 556

# %%
nrows = 4
ncols = 4

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 100
next_ferrari_pix = [os.path.join(train_ferrari_dir, fname) for fname in train_ferrari_names[pic_index-8:pic_index]]
next_porsche_pix = [os.path.join(train_porsche_dir, fname) for fname in train_porsche_names[pic_index-8:pic_index]]

next_ferrari_pix
next_porsche_pix
# Out:
# ['/home/fabian/carclass/porsche/train/wp2144799.jpg',
#  '/home/fabian/carclass/porsche/train/fSWgJM.jpg',
#  '/home/fabian/carclass/porsche/train/2018-Porsche-718-Cayman-GTS-V2-1080.jpg',
#  '/home/fabian/carclass/porsche/train/2020-Porsche-911-C4S-interior.jpg',
#  '/home/fabian/carclass/porsche/train/2019-porsche-macan-suv-02.jpg',
#  '/home/fabian/carclass/porsche/train/606393.jpg',
#  '/home/fabian/carclass/porsche/train/355783.jpg',
#  '/home/fabian/carclass/porsche/train/2019-Porsche-Macan-white-color-front-profile-4k-hd-wallpaper.jpg']

# %%
for i, img_path in enumerate(next_ferrari_pix+next_porsche_pix):
    sp = plt.subplot(nrows, ncols, i + 1)
    sp.axis('Off') 

    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid') 
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 298, 298, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 147, 147, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 71, 71, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 33, 33, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1606144
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,704,097
# Trainable params: 1,704,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr=0.001),
              metrics = ['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
        '/home/fabian/carclass/',  
        target_size=(300, 300),  
        batch_size=100,
        class_mode='binary')

validation_generator = validation_datagen.flow_from_directory(
        '/home/fabian/carval/',
        target_size=(300, 300), 
        batch_size=20,
        class_mode='binary')
# Out:
# Found 1004 images belonging to 2 classes.
# Found 202 images belonging to 2 classes.

# %%
history = model.fit(train_generator, steps_per_epoch=3, epochs=100, verbose=1, validation_data = validation_generator,
      validation_steps=8)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 3 steps, validate for 8 steps
# Epoch 1/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.5622 - accuracy: 0.7167 - val_loss: 0.8924 - val_accuracy: 0.6375
# Epoch 2/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.6830 - accuracy: 0.6500 - val_loss: 0.5895 - val_accuracy: 0.6500
# Epoch 3/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.5762 - accuracy: 0.7433 - val_loss: 0.5748 - val_accuracy: 0.6562
# Epoch 4/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.5673 - accuracy: 0.7100 - val_loss: 0.5659 - val_accuracy: 0.6562
# Epoch 5/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.5354 - accuracy: 0.7267 - val_loss: 0.6299 - val_accuracy: 0.6750
# Epoch 6/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.5894 - accuracy: 0.7067 - val_loss: 0.5770 - val_accuracy: 0.6687
# Epoch 7/100
# 3/3 [==============================] - 22s 7s/step - loss: 0.6084 - accuracy: 0.7067 - val_loss: 0.6140 - val_accuracy: 0.6625
# Epoch 8/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.5602 - accuracy: 0.7300 - val_loss: 0.5634 - val_accuracy: 0.6500
# Epoch 9/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.5052 - accuracy: 0.7255 - val_loss: 0.7448 - val_accuracy: 0.6875
# Epoch 10/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.6105 - accuracy: 0.6967 - val_loss: 0.5626 - val_accuracy: 0.6562
# Epoch 11/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.5165 - accuracy: 0.7700 - val_loss: 0.5885 - val_accuracy: 0.6938
# Epoch 12/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.5249 - accuracy: 0.7304 - val_loss: 0.5793 - val_accuracy: 0.6812
# Epoch 13/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.4745 - accuracy: 0.7304 - val_loss: 0.5624 - val_accuracy: 0.6562
# Epoch 14/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.4951 - accuracy: 0.7733 - val_loss: 0.5572 - val_accuracy: 0.6500
# Epoch 15/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.4076 - accuracy: 0.7598 - val_loss: 0.5645 - val_accuracy: 0.6438
# Epoch 16/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.3950 - accuracy: 0.7500 - val_loss: 0.5979 - val_accuracy: 0.6938
# Epoch 17/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.5652 - accuracy: 0.7067 - val_loss: 0.5582 - val_accuracy: 0.6687
# Epoch 18/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.3947 - accuracy: 0.7647 - val_loss: 0.6111 - val_accuracy: 0.6875
# Epoch 19/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.4841 - accuracy: 0.7967 - val_loss: 0.6471 - val_accuracy: 0.6687
# Epoch 20/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.4467 - accuracy: 0.7800 - val_loss: 1.0693 - val_accuracy: 0.6938
# Epoch 21/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.5233 - accuracy: 0.7598 - val_loss: 0.5696 - val_accuracy: 0.6875
# Epoch 22/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.4719 - accuracy: 0.7700 - val_loss: 0.8656 - val_accuracy: 0.5312
# Epoch 23/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.5797 - accuracy: 0.7300 - val_loss: 0.5564 - val_accuracy: 0.6750
# Epoch 24/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.4935 - accuracy: 0.7433 - val_loss: 0.5339 - val_accuracy: 0.6812
# Epoch 25/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.4209 - accuracy: 0.7767 - val_loss: 0.5981 - val_accuracy: 0.6500
# Epoch 26/100
# 3/3 [==============================] - 17s 6s/step - loss: 0.4105 - accuracy: 0.7206 - val_loss: 0.5252 - val_accuracy: 0.7063
# Epoch 27/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.3270 - accuracy: 0.7892 - val_loss: 0.5290 - val_accuracy: 0.7375
# Epoch 28/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.3775 - accuracy: 0.8300 - val_loss: 0.6312 - val_accuracy: 0.6500
# Epoch 29/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.3483 - accuracy: 0.8533 - val_loss: 0.5754 - val_accuracy: 0.7063
# Epoch 30/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.6014 - accuracy: 0.6600 - val_loss: 0.6543 - val_accuracy: 0.6000
# Epoch 31/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.4681 - accuracy: 0.8267 - val_loss: 0.5662 - val_accuracy: 0.6875
# Epoch 32/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.4117 - accuracy: 0.8067 - val_loss: 0.5416 - val_accuracy: 0.7063
# Epoch 33/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.3729 - accuracy: 0.8533 - val_loss: 0.5385 - val_accuracy: 0.7250
# Epoch 34/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.3121 - accuracy: 0.8733 - val_loss: 0.5849 - val_accuracy: 0.7125
# Epoch 35/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.3716 - accuracy: 0.8400 - val_loss: 0.6519 - val_accuracy: 0.6375
# Epoch 36/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.4036 - accuracy: 0.8000 - val_loss: 0.6836 - val_accuracy: 0.6562
# Epoch 37/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.3755 - accuracy: 0.7304 - val_loss: 0.5258 - val_accuracy: 0.7375
# Epoch 38/100
# 3/3 [==============================] - 17s 6s/step - loss: 0.3593 - accuracy: 0.8433 - val_loss: 0.5476 - val_accuracy: 0.7000
# Epoch 39/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.2015 - accuracy: 0.9069 - val_loss: 0.5965 - val_accuracy: 0.7312
# Epoch 40/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.5076 - accuracy: 0.8167 - val_loss: 0.5444 - val_accuracy: 0.7125
# Epoch 41/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.3313 - accuracy: 0.8867 - val_loss: 0.5661 - val_accuracy: 0.7500
# Epoch 42/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.2821 - accuracy: 0.9000 - val_loss: 0.5429 - val_accuracy: 0.7125
# Epoch 43/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.3110 - accuracy: 0.8900 - val_loss: 0.5646 - val_accuracy: 0.7188
# Epoch 44/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.1804 - accuracy: 0.9216 - val_loss: 0.6867 - val_accuracy: 0.7063
# Epoch 45/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.1912 - accuracy: 0.9118 - val_loss: 0.6279 - val_accuracy: 0.7188
# Epoch 46/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.2836 - accuracy: 0.8667 - val_loss: 0.7018 - val_accuracy: 0.6562
# Epoch 47/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.2874 - accuracy: 0.8235 - val_loss: 0.5428 - val_accuracy: 0.7375
# Epoch 48/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.1714 - accuracy: 0.9265 - val_loss: 0.6540 - val_accuracy: 0.7250
# Epoch 49/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.1676 - accuracy: 0.9333 - val_loss: 0.7900 - val_accuracy: 0.6812
# Epoch 50/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.4300 - accuracy: 0.8367 - val_loss: 0.8963 - val_accuracy: 0.6000
# Epoch 51/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.5804 - accuracy: 0.6967 - val_loss: 0.5659 - val_accuracy: 0.7125
# Epoch 52/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.2844 - accuracy: 0.8867 - val_loss: 0.6231 - val_accuracy: 0.7000
# Epoch 53/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.1550 - accuracy: 0.9533 - val_loss: 0.6920 - val_accuracy: 0.7250
# Epoch 54/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.2107 - accuracy: 0.9200 - val_loss: 0.6521 - val_accuracy: 0.7312
# Epoch 55/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.0868 - accuracy: 0.9657 - val_loss: 0.7075 - val_accuracy: 0.7250
# Epoch 56/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.1176 - accuracy: 0.9461 - val_loss: 0.7113 - val_accuracy: 0.7250
# Epoch 57/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.0699 - accuracy: 0.9767 - val_loss: 0.7806 - val_accuracy: 0.7375
# Epoch 58/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.2822 - accuracy: 0.8933 - val_loss: 0.9333 - val_accuracy: 0.6313
# Epoch 59/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.2822 - accuracy: 0.8867 - val_loss: 0.7548 - val_accuracy: 0.6812
# Epoch 60/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.1310 - accuracy: 0.9567 - val_loss: 0.7460 - val_accuracy: 0.7250
# Epoch 61/100
# 3/3 [==============================] - 17s 6s/step - loss: 0.0576 - accuracy: 0.9867 - val_loss: 0.8695 - val_accuracy: 0.7312
# Epoch 62/100
# 3/3 [==============================] - 17s 6s/step - loss: 0.1216 - accuracy: 0.9216 - val_loss: 0.9192 - val_accuracy: 0.7125
# Epoch 63/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0822 - accuracy: 0.9510 - val_loss: 0.9086 - val_accuracy: 0.7250
# Epoch 64/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.2869 - accuracy: 0.9167 - val_loss: 0.7073 - val_accuracy: 0.6812
# Epoch 65/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.1035 - accuracy: 0.9412 - val_loss: 0.7679 - val_accuracy: 0.7000
# Epoch 66/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.1757 - accuracy: 0.9300 - val_loss: 0.7736 - val_accuracy: 0.7375
# Epoch 67/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.0793 - accuracy: 0.9667 - val_loss: 0.8506 - val_accuracy: 0.7063
# Epoch 68/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.1142 - accuracy: 0.9500 - val_loss: 0.8677 - val_accuracy: 0.7500
# Epoch 69/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.0244 - accuracy: 0.9967 - val_loss: 0.9700 - val_accuracy: 0.7250
# Epoch 70/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.0272 - accuracy: 0.9933 - val_loss: 1.0942 - val_accuracy: 0.7125
# Epoch 71/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.0258 - accuracy: 0.9933 - val_loss: 1.0361 - val_accuracy: 0.7375
# Epoch 72/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.1840 - accuracy: 0.9133 - val_loss: 1.7471 - val_accuracy: 0.6000
# Epoch 73/100
# 3/3 [==============================] - 17s 6s/step - loss: 0.4496 - accuracy: 0.7500 - val_loss: 6.5364 - val_accuracy: 0.5125
# Epoch 74/100
# 3/3 [==============================] - 20s 7s/step - loss: 1.3652 - accuracy: 0.8533 - val_loss: 0.7169 - val_accuracy: 0.7125
# Epoch 75/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.1641 - accuracy: 0.9467 - val_loss: 0.7298 - val_accuracy: 0.7188
# Epoch 76/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.1002 - accuracy: 0.9600 - val_loss: 0.8346 - val_accuracy: 0.7188
# Epoch 77/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.0947 - accuracy: 0.9700 - val_loss: 0.7928 - val_accuracy: 0.7312
# Epoch 78/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.0895 - accuracy: 0.9700 - val_loss: 0.8644 - val_accuracy: 0.7250
# Epoch 79/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.0262 - accuracy: 0.9967 - val_loss: 0.9744 - val_accuracy: 0.7500
# Epoch 80/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0707 - accuracy: 0.9706 - val_loss: 0.9813 - val_accuracy: 0.7312
# Epoch 81/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.0444 - accuracy: 0.9833 - val_loss: 1.0013 - val_accuracy: 0.7375
# Epoch 82/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.1909 - accuracy: 0.9400 - val_loss: 0.9866 - val_accuracy: 0.7188
# Epoch 83/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.0666 - accuracy: 0.9833 - val_loss: 0.8122 - val_accuracy: 0.7250
# Epoch 84/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.9430 - val_accuracy: 0.7312
# Epoch 85/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.0976 - accuracy: 0.9412 - val_loss: 0.9225 - val_accuracy: 0.7188
# Epoch 86/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.0331 - accuracy: 0.9933 - val_loss: 0.9764 - val_accuracy: 0.7500
# Epoch 87/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.0485 - accuracy: 0.9833 - val_loss: 0.9931 - val_accuracy: 0.7375
# Epoch 88/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0130 - accuracy: 0.9951 - val_loss: 1.1600 - val_accuracy: 0.7375
# Epoch 89/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 1.2119 - val_accuracy: 0.7312
# Epoch 90/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.0485 - accuracy: 0.9800 - val_loss: 1.4174 - val_accuracy: 0.6938
# Epoch 91/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.1534 - accuracy: 0.9069 - val_loss: 2.6740 - val_accuracy: 0.5688
# Epoch 92/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.5789 - accuracy: 0.8000 - val_loss: 0.7269 - val_accuracy: 0.7563
# Epoch 93/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.0607 - accuracy: 0.9933 - val_loss: 0.8236 - val_accuracy: 0.7437
# Epoch 94/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.8875 - val_accuracy: 0.7437
# Epoch 95/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.0455 - accuracy: 0.9833 - val_loss: 0.8547 - val_accuracy: 0.7688
# Epoch 96/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.9756 - val_accuracy: 0.7563
# Epoch 97/100
# 3/3 [==============================] - 17s 6s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.0406 - val_accuracy: 0.7500
# Epoch 98/100
# 3/3 [==============================] - 17s 6s/step - loss: 0.0192 - accuracy: 0.9967 - val_loss: 1.0927 - val_accuracy: 0.7563
# Epoch 99/100
# 3/3 [==============================] - 20s 7s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.1692 - val_accuracy: 0.7500
# Epoch 100/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0122 - accuracy: 0.9902 - val_loss: 1.2057 - val_accuracy: 0.7500

# %%
successive_outputs = [layer.output for layer in model.layers[1:]]
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)

ferrari_img_files = [os.path.join(train_ferrari_dir, f) for f in train_ferrari_names]
porsche_img_files = [os.path.join(train_porsche_dir, f) for f in train_porsche_names]
img_path = random.choice(ferrari_img_files + porsche_img_files)

img = load_img(img_path, target_size=(300, 300))
x = img_to_array(img)
x = x.reshape((1,) + x.shape)

x /= 255

successive_feature_maps = visualization_model.predict(x)

# %%
layer_names = [layer.name for layer in model.layers]

for layer_name, feature_map in zip(layer_names, successive_feature_maps):
    if len(feature_map.shape) == 4:
        n_features = feature_map.shape[-1]  
        size = feature_map.shape[1]
        
        display_grid = np.zeros((size, size * n_features))
        for i in range(n_features):
            x = feature_map[0, :, :, i]
            x -= x.mean()
            x /= x.std()
            x *= 64
            x += 128
            x = np.clip(x, 0, 255).astype('uint8')
            display_grid[:, i * size : (i + 1) * size] = x
        
        scale = 20. / n_features
        plt.figure(figsize=(scale * n_features, scale))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in true_divide
#   if sys.path[0] == '':

# %%
import numpy as np
from tensorflow import keras
from keras.preprocessing import image

path = '/home/fabian/'
img = image.load_img(path, target_size=(300,300,3))
x = image.img_to_array(img)
    
x=np.expand_dims(x, axis=0)
images = np.vstack([x])

classes = model.predict(images, batch_size=10)

print(classes[0])

if classes[0]>0:
    print(path + " is a porsche")
else:
    print(path + " is a ferrari")
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-78d5bd8c056b> in <module>
#       4
#       5 path = '/home/fabian/carclass/porsche/validation/VixYnE.jpg'
# ----> 6 img = image.load_img(path, target_size=(300,300,3))
#       7 x = image.img_to_array(img)
#       8
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     108         raise ImportError('Could not import PIL.Image. '
#     109                           'The use of `load_img` requires PIL.')
# --> 110     img = pil_image.open(path)
#     111     if color_mode == 'grayscale':
#     112         if img.mode != 'L':
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/fabian/carclass/porsche/validation/VixYnE.jpg'
